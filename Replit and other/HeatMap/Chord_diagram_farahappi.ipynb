# %%
import holoviews as hv
from holoviews import opts, dim
# from bokeh.sampledata.airport_routes import routes, airports

# hv.extension('bokeh')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\mirza\miniconda3\envs\python_eda\Lib\site-packages\requests\compat.py:11
#      10 try:
# ---> 11     import chardet
#      12 except ImportError:
#
# ModuleNotFoundError: No module named 'chardet'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import holoviews as hv
#       2 from holoviews import opts, dim
#       3 # from bokeh.sampledata.airport_routes import routes, airports
#       4
#       5 # hv.extension('bokeh')
#
# File c:\Users\mirza\miniconda3\envs\python_eda\Lib\site-packages\holoviews\__init__.py:115
#     111 warnings.filterwarnings("ignore",
#     112                         message="elementwise comparison failed; returning scalar instead")
#     114 if "IPython" in sys.modules:
# --> 115     from .ipython import notebook_extension
#     116     extension = notebook_extension # noqa (name remapping)
#     117 else:
#
# File c:\Users\mirza\miniconda3\envs\python_eda\Lib\site-packages\holoviews\ipython\__init__.py:15
#      13 from ..core.tree import AttrTree
#      14 from ..element.comparison import ComparisonTestCase
# ---> 15 from ..plotting.renderer import Renderer
#      16 from ..util import extension
#      17 from .display_hooks import display, png_display, pprint_display, svg_display
#
# File c:\Users\mirza\miniconda3\envs\python_eda\Lib\site-packages\holoviews\plotting\__init__.py:13
#      11 from ..operation.stats import bivariate_kde, univariate_kde
#      12 from .plot import Plot
# ---> 13 from .renderer import HTML_TAGS, Renderer  # noqa (API import)
#      14 from .util import apply_nodata, flatten_stack, list_cmaps  # noqa (API import)
#      16 Compositor.register(Compositor("Image", apply_nodata, None,
#      17                                'data', transfer_options=True,
#      18                                transfer_parameters=True,
#      19                                output_type=Image,
#      20                                backends=['bokeh', 'matplotlib', 'plotly']))
#
# File c:\Users\mirza\miniconda3\envs\python_eda\Lib\site-packages\holoviews\plotting\renderer.py:11
#       8 from functools import partial
#       9 from io import BytesIO, StringIO
# ---> 11 import panel as pn
#      12 import param
#      13 from bokeh.document import Document
#
# File c:\Users\mirza\miniconda3\envs\python_eda\Lib\site-packages\panel\__init__.py:50
#       1 """
#       2 Panel is a high level app and dashboarding framework
#       3 ====================================================
#    (...)
#      46 https://panel.holoviz.org/getting_started/index.html
#      47 """
#      48 from param import rx
# ---> 50 from . import chat  # noqa
#      51 from . import layout  # noqa
#      52 from . import links  # noqa
#
# File c:\Users\mirza\miniconda3\envs\python_eda\Lib\site-packages\panel\chat\__init__.py:31
#       1 """
#       2 Panel chat makes creating chat components easy
#       3 ==============================================================
#    (...)
#      29 https://panel.holoviz.org/reference/chat/ChatInterface.html
#      30 """
# ---> 31 from . import langchain  # noqa
#      32 from .feed import ChatFeed  # noqa
#      33 from .icon import ChatReactionIcons  # noqa
#
# File c:\Users\mirza\miniconda3\envs\python_eda\Lib\site-packages\panel\chat\langchain.py:18
#      15     AgentFinish = None
#      16     LLMResult = None
# ---> 18 from ..chat.feed import ChatFeed
#      19 from ..chat.interface import ChatInterface
#      20 from ..chat.message import DEFAULT_AVATARS
#
# File c:\Users\mirza\miniconda3\envs\python_eda\Lib\site-packages\panel\chat\feed.py:28
#      26 from ..pane.image import SVG, ImageBase
#      27 from ..widgets.button import Button
# ---> 28 from .message import ChatMessage
#      30 if TYPE_CHECKING:
#      31     from bokeh.document import Document
#
# File c:\Users\mirza\miniconda3\envs\python_eda\Lib\site-packages\panel\chat\message.py:32
#      30 from ..viewable import Viewable
#      31 from ..widgets.base import Widget
# ---> 32 from .icon import ChatCopyIcon, ChatReactionIcons
#      34 if TYPE_CHECKING:
#      35     from bokeh.document import Document
#
# File c:\Users\mirza\miniconda3\envs\python_eda\Lib\site-packages\panel\chat\icon.py:8
#       5 from typing import ClassVar, List
#       7 import param
# ----> 8 import requests
#      10 from ..io.cache import cache
#      11 from ..io.resources import CDN_DIST
#
# File c:\Users\mirza\miniconda3\envs\python_eda\Lib\site-packages\requests\__init__.py:45
#      41 import warnings
#      43 import urllib3
# ---> 45 from .exceptions import RequestsDependencyWarning
#      47 try:
#      48     from charset_normalizer import __version__ as charset_normalizer_version
#
# File c:\Users\mirza\miniconda3\envs\python_eda\Lib\site-packages\requests\exceptions.py:9
#       1 """
#       2 requests.exceptions
#       3 ~~~~~~~~~~~~~~~~~~~
#       4
#       5 This module contains the set of Requests' exceptions.
#       6 """
#       7 from urllib3.exceptions import HTTPError as BaseHTTPError
# ----> 9 from .compat import JSONDecodeError as CompatJSONDecodeError
#      12 class RequestException(IOError):
#      13     """There was an ambiguous exception that occurred while handling your
#      14     request.
#      15     """
#
# File c:\Users\mirza\miniconda3\envs\python_eda\Lib\site-packages\requests\compat.py:13
#      11     import chardet
#      12 except ImportError:
# ---> 13     import charset_normalizer as chardet
#      15 import sys
#      17 # -------
#      18 # Pythons
#      19 # -------
#      20
#      21 # Syntax sugar.
#
# File c:\Users\mirza\miniconda3\envs\python_eda\Lib\site-packages\charset_normalizer\__init__.py:23
#       1 """
#       2 Charset-Normalizer
#       3 ~~~~~~~~~~~~~~
#    (...)
#      21 :license: MIT, see LICENSE for more details.
#      22 """
# ---> 23 from charset_normalizer.api import from_fp, from_path, from_bytes, normalize
#      24 from charset_normalizer.legacy import detect
#      25 from charset_normalizer.version import __version__, VERSION
#
# File c:\Users\mirza\miniconda3\envs\python_eda\Lib\site-packages\charset_normalizer\api.py:10
#       7     PathLike = Union[str, 'os.PathLike[str]']  # type: ignore
#       9 from charset_normalizer.constant import TOO_SMALL_SEQUENCE, TOO_BIG_SEQUENCE, IANA_SUPPORTED
# ---> 10 from charset_normalizer.md import mess_ratio
#      11 from charset_normalizer.models import CharsetMatches, CharsetMatch
#      12 from warnings import warn
#
# AttributeError: partially initialized module 'charset_normalizer' has no attribute 'md__mypyc' (most likely due to a circular import)
