# %%
# Create Dictionaries
dictionary = {
    'name' : 'Rehan',
    'age' : 25,
}
print(dictionary['name'])
print(dictionary['age'])
dictionary['age'] = 30
print(dictionary)
print(dictionary['age'])
# Out:
# Rehan
# 25
# {'name': 'Rehan', 'age': 30}
# 30

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# name Card
name = input("Enter your name: ")
dob = input('Please enter your date of birth: ')
tel = input('Please enter your phone number: ')
eml = input('Please enter your email address: ')
add = input('Please enter your address: ')


dictionary = {
    'name' : name,
    'Date of Birth' : dob,
    'Telephone' : tel,
    'Email' : eml,
    'Address' : add
}
print(dictionary)
# Out:
# {'name': 'Rehan', 'Date of Birth': '11-05-1999', 'Telephone': '+92-3015900054', 'Email': 'm.rehankhalid786@gmail.com', 'Address': 'p-1376/2, St# 05, Nasirabad, Nishatabad'}
