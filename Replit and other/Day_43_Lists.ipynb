# %% [markdown]
# # Lists

# %%
# lists enter the 2D data 
my_2D_lis = [['Johny', 21, 'Mac'],
            ['Rehan', 32 , 'PC'],
            ['Hassna', 42, 'Mav']]
print(my_2D_lis[1][0])
# Out:
# Rehan

# %% [markdown]
# ![image.png](attachment:9f306159-a715-45e8-8b89-d94c6c3c96e2.png)

# %%
# Challange randomly generate number between 0 and 90
# alloocate into these numerical list
# center square should not have any number stored but it should contain BINGO in it
import random

def ran():
    num = random.randint(1,90)
    return num
for i in range(8):
    
print(num)
# lists enter the 2D data 
my_2D_lis = [[num, num , num],
            [num, 'BINGO' , num],
            [num, num, num]]
print(my_2D_lis[1][0])
# Out:
# 66
# 66

# %%
import random
bingo = []
def ran():
  number = random.randint(1,90)
  return number
def prettyPrint():
  for row in bingo:
    print(row)
numbers = []
for i in range(8):
  numbers.append(ran())
numbers.sort()
bingo = [ [ numbers[0], numbers[1], numbers[2]],
          [ numbers[3], "BINGO", numbers[4] ],
          [ numbers [5], numbers[6], numbers[7]]
        ]
prettyPrint()
# Out:
# [2, 17, 19]
# [38, 'BINGO', 50]
# [59, 63, 73]
