# %% [markdown]
# ### `Mean values and its types`
# - Arithmatic Mean
#   - Summ of all value / counts of the values => x = Sigma X/n
# - Geomatric Mean
#   - multiply all values and then take underoot with poerr of the number of values
#     - [12,13,14,13,15,16]*1/6
# - Harmonic Mean
#   - its the inverse of the Arithmatic mean
#   -  n/sigma x, to get velocity and acceleration and exact values
#   -

# %%
import numpy as np
import statistics as st
import pandas as pd
import seaborn as sns
from scipy import stats
df = sns.load_dataset('titanic')
x = [12,13,15,16,18]
print(np.mean(x))
print(st.geometric_mean(x))
print(st.harmonic_mean(x))
# Out:
# 14.8
# 14.646089004871582
# 14.493651285227624

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, 1 to 889
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     182 non-null    int64
#  1   pclass       182 non-null    int64
#  2   sex          182 non-null    object
#  3   age          182 non-null    float64
#  4   sibsp        182 non-null    int64
#  5   parch        182 non-null    int64
#  6   fare         182 non-null    float64
#  7   embarked     182 non-null    object
#  8   class        182 non-null    category
#  9   who          182 non-null    object
#  10  adult_male   182 non-null    bool
#  11  deck         182 non-null    category
#  12  embark_town  182 non-null    object
#  13  alive        182 non-null    object
#  14  alone        182 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 18.2+ KB

# %%
df['fare'].mean()
df = df.dropna()
# df.isnull().sum()
# st.geometric_mean(df['fare'])
print(st.mean(df['age']))
print(stats.gmean(df['age']))
print(stats.hmean(df['age']))
# Out:
# 35.62318681318681
# 30.1549986476529
# 17.873143215116944

# %%
# Mean choice depends over the type of Data
# stats.trim_mean(df, 0.01)

# %% [markdown]
# ### Limitations of Mean
# - sensitive to outliers
# -  does not account for skewness or kurtosis
# -  does not tell full story

# %% [markdown]
# ### `Range`
# - 1. Central Tendency (Mean, Median, Mode)
# - 2. Dispersion (Variablity/Spread, Range, IQR, Variance, Standerd Deviation, Standerd Error)
#   - Range is Maximum, to minimum values of that data set
#   - Span of data defined as the, => span = largetst value - smallest value

# %%
import numpy as np
df = np.array([10,20,30,40,50])
np.ptp(df) # range
# Out:
# 40

# %%
# Inter Quartile Range
Q1 = np.percentile(df, 60)
Q1
# Out:
# 34.0

# %% [markdown]
# ### inter quartile range IQR
# - Q1,Q2,Q3,Q4
# - IQR = Q3-Q1 mostly used
# - To calculate
#   - sort the data in ascending order
#   - find the quartiles find Q1, Q2 and Q3 Q4
#   - then we will substract Q3-Q1 = IQR
#   -  IQR = 25th percentile - 75th percentile
#   -
# ![image-2.png](attachment:image-2.png)

# %%
df = np.array([5,2,6,8,15,12,18,22,20])
Q1 = np.percentile(df, 25)
Q3 = np.percentile(df, 75)
IQR = Q3 - Q1
IQR
IQR_min = Q1 - 1.5 * IQR
IQR_max = Q1 + 1.5 * IQR
print(IQR_max)
print(IQR_min)
# Out:
# 24.0
# -12.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Genrate a data set with potential outliers

np.random.seed(0)
data = np.random.normal(100, 20, 200)
data = np.append(data, [300, 5])
# calculate IQR
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
print(IQR)
# find upper and lower bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q1 + 1.5 * IQR
print(lower_bound)
print(upper_bound)

# identify the outiers
outliers = (data < lower_bound) | (data > upper_bound)
print(outliers)
# data without ouliers
with_no_out = data[~outliers]
# plot the two graphs
plt.figure(figsize = (14,6))
plt.subplot(1,2,1)
sns.boxplot(data = data)
plt.title('Origianl graph with outliers')
# plot after the outlier removal
plt.subplot(1,2,2)
sns.boxplot(data = with_no_out)
plt.title('Data after removing the outloers')
plt.show()
# Out:
# 30.931128532964465
# 39.03702295602679
# 131.83040855492018
# [ True False False  True  True False False False False False False False
#  False False False False False False False False False False False False
#   True False False False False False False False False False False False
#  False False False False False False False  True False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False  True False False False False False False False False False False
#  False  True False False  True False False False False  True False False
#   True False  True False False  True False False False False False False
#  False False False False False False False  True False False False False
#  False False False False False False False False False False False False
# ...

# %% [markdown]
# ### Varience
# - Populatin variance
#   - you have to minus the individual value from the (micro) u means population mean and then take square of that
#     - value and divide it by the number N.
# - Sample Variance
#   - it is similar to above, you have to minus the indivifual value from sample mean which is Xbar and then take square
#     - of them and then we have to divide it by n-1
#   -

# %%
# import libraries
import numpy as np
df = np.array([2,3,4,5,6])
mean =np.mean(df)
print(mean)
var = np.var(df, ddof=1)
print(var)
# Out:
# 4.0
# 2.5

# %% [markdown]
# ### Standerd Deviation
# - amount of variation or dispersion of the data
# - low std means the less dispersion and smooth deviation
# -  high std means the more dispersion and high deviation
# -  std is the square root of variance
# -

# %%
df = np.array([2,3,4,5,6])
std = np.std(df, ddof=1)
std
# Out:
# 1.5811388300841898

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Standerd deviation
# -  if std = 1 then it has almost 67.7 or 68% data
# -  if std = 2 then it has almost 95% data in it
# -  if std = 3 then it has almost 99.7% of all data
# ![image.png](attachment:image.png)

# %% [markdown]
# # Data Distributions
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
