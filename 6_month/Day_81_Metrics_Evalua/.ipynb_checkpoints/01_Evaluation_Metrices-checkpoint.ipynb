# %% [markdown]
# # Evaluation Matrices
# - Regression
# - Classification
# - Clustering
# - ![image.png](attachment:b12fd2e3-6b0c-4a7a-84e6-ad56c883eded.png)

# %% [markdown]
# ![image.png](attachment:b94c4591-c01a-414f-948b-053525b26a52.png)
# ![image.png](attachment:a2bc75c0-adff-49b8-90ed-55959c11b301.png)

# %% [markdown]
# # Evalution Matrix for Regression
# - MAE mean absolute error
#     - Redline in center of the regression plot, this is called error and if calculated it is calle mean absolute error
#     ![image.png](attachment:abdd8fc6-1100-4a6e-980d-d586a69abc94.png)
#     ![image.png](attachment:eda531e6-d784-45c7-82ce-18729e7bf7b9.png)
# - Mean Squared Error
#   ![image.png](attachment:ad3d39f6-b154-405e-a4a5-c57c2f016e49.png)
#   -
