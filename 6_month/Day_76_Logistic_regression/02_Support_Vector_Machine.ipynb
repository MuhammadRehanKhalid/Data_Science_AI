# %% [markdown]
# # Support Vector Machine
# - Hyper plane
#     - which separate the two planes or vectors and make them different
#     - these lines are at the differential planes of the both points along the boundry
#       wals
# - SVMS are used
#     - Mostly used for Classification (SVC)
#         - SVC with linear kernel
#         - Linear SVC
#         - SVC with RBF Kernel
#             - Radial Basis Function(RBF)
#             ![image.png](attachment:3f800085-db4d-4e94-b228-ef83ad07b406.png)
#         - SVC with polynomial (Degree_03)
#         ![image.png](attachment:dd707be2-126a-4b36-8dae-671fafe7ced0.png)
#     - Sometimes for Regression (SVR)
#     - Rarely and might be used for Outlier detections
# - Application of SVM
#     - Image Classification
#     - Text and hyper text categorization
#     - Bioinfo_Proteon classificaton
#     - Handwriting classificaiton
# - Ir can be applied on linear or non linear data
# - ![image.png](attachment:8b7be168-d749-4036-a1cc-08e435f9b5fc.png)
