# %% [markdown]
# # K_Nearest Clusters
# ### A man is Known by the company he Keeps
# ### or a `data point is know by a company he keeps`

# %% [markdown]
# # It give the nearest points depending upon the requirements
# - It will circle and make clusters based on the neighbours presen in the data
# - We Might take mean or median of the dataset
# - Advantages of this is
#     - Simple, best, less need of the training
#     - keep values in limit and it predicts according to the data
#     - Versatile algorithem
# - Different types of distances used in this algorithem
#     -  Eucledian distance
#     -  Manhattan Distance
#     -  Minknwonski distance
#     -  Hamming Distance
#         - We basically use first 3
# - Disadvantages
#     - Computationally expensive
#     - sensitive to imbalance (one class has less values, oterh has more values) data, outliers, or biased data
#     - sensitive to irrelevant feature, we need to find relevvant feature
# - Where to Use KNN's
#     - Recomendation system
#     - Financial Services
#     - Banking loan system
#         - Fraud Detection
#     - Health Care system, how healthy etc, factors for health
#     - many more
# - We can also use this for
#     - Regressoin using mean, or median in KNN
#     - Classification (we use mode for this) in KNN
# - Question is how we can find neighbours
#     -

# %% [markdown]
# # Eucledian distance

# %% [markdown]
# - Eucledian distance (Distance from one point to the other)
#     - distance between 2 point like p and q
#     - Use pythgorous theorem to calcualte the hyp2 = base2 + alt2
#     - ![image.png](attachment:81eca0a1-9d95-47c2-ae67-2ee965af7846.png)

# %% [markdown]
# - ![image.png](attachment:9fb90416-8f98-4da4-b446-59c98fb0cd40.png)
# - ![image.png](attachment:d21c7fdc-2b54-4ad6-a63b-f93695d0f6fb.png)

# %% [markdown]
# # Manhattan Distance

# %% [markdown]
# - Block to block and square to sqaure distance
# ![image.png](attachment:2264b65d-ba43-42e7-859b-82a663cfcc48.png)

# %% [markdown]
# - Formula
# The formula for the Manhattan distance between two points (x1, y1) and (x2, y2) is |x1 - x2| + |y1 - y2|.
# ![image.png](attachment:83b449c2-6f27-44e7-a0a6-ebfdc908ad1b.png)

# %% [markdown]
# # Minkpwski Distance
# - Generalized for of Minskowsky Distance
# - ![image.png](attachment:5c0711ca-65ac-4250-8404-788a6e1974b4.png)
# - ![image.png](attachment:d971b4be-3ab5-43fd-a6ea-1eb9959c0098.png)
# -

# %% [markdown]
# # Hamming Distance
# - Hamming Distance refers to the number of positions at which two strings of the same length differ. It is a metric used in computer science to measure dissimilarity between strings. AI generated definition based on: Cybersecurity and Applied Mathematics, 2016.

# %%
# Example of KNN Classifies on IRIS
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors

# %%
# Load dataset
df = sns.load_dataset('iris')

# %%
# lets define X ans y in our data
X = df.drop('species', axis=1)
y = df['species']
