# %% [markdown]
# # `Assignment:`
#
# 1. Read the documentation of each website: `pandas, matplotlib, seabron and plotly`
# 2. Make 10 different plots on different datasets each time using each of these four libraries.
# 3. Interpret them and provide the insights you take from each plot in 3-4 lines.
# 4. Finalize one notebook and send it to me via discord.
#
# ✅[Our Discord group of Current Course](https://discord.gg/QpvUKEtUJD)

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly as py
import nbformat as nb

# %% [markdown]
# # `First Data Set 'Flights'`

# %%
df = sns.load_dataset('flights')

# %%
#Check data set
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    datetime64[ns]
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), datetime64[ns](1), int64(1)
# memory usage: 2.9 KB
#         year month  passengers
# 0 1949-01-01   Jan         112
# 1 1949-01-01   Feb         118
# 2 1949-01-01   Mar         132
# 3 1949-01-01   Apr         129
# 4 1949-01-01   May         121

# %%
df.plot(kind='scatter', x = 'year', y = 'passengers', c = 'month', colormap = 'viridis')
plt.xlabel('Year of Flights')
plt.ylabel('Number of Passengers Travelled')
plt.title('Year Wise Passenger Numbers during different Months')
# Out:
# Text(0.5, 1.0, 'Year Wise Passenger Numbers during different Months')

# %%
df.plot(kind = 'hist', x = 'month', y = 'passengers', colormap = 'viridis')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Convert the 'Year' column to datetime
# df['year'] = pd.to_datetime(df['year'], format='%Y')

# Create a line plot for the number of flights over time
plt.figure(figsize=(6,6))
plt.plot(df['year'],df['month'])
plt.xlabel('year')
plt.ylabel('Number of Flights')
plt.title('Number of Flights Over Time')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your DataFrame df is in the format as follows:
# year	month	passengers
# 0	1949-01-01	Jan	112
# 1	1949-01-01	Feb	112
# ...

# To plot a heatmap, you first need to create a pivot table with year as the index, month as the columns, and passengers as the values
df_pivot = df.pivot_table(index='year', columns='month', values='passengers')

# Create a mask for the years you want to include in the heatmap
mask = df_pivot.index.isin([1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# Filter the dataframe based on the mask
df_filtered = df_pivot.loc[mask]

# Generate a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_filtered, annot=True, cmap='RdYlBu', fmt=".0f")
plt.title('Yearly Passenger Trend')
plt.xlabel('Month')
plt.ylabel('Year')
plt.show()

# %%
df.groupby('month')['passengers'].mean().plot(kind = 'bar', colormap = 'viridis')
# Out:
# C:\Users\mirza\AppData\Local\Temp\ipykernel_12928\1948424337.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('month')['passengers'].mean().plot(kind = 'bar', colormap = 'viridis')
# <Axes: xlabel='month'>

# %%
sns.barplot(data = df, x='month', y = 'passengers', hue='year')
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
import seaborn as sns
sns.set_theme(style="ticks")
sns.pairplot(df, hue="month")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights = (
    flights_long
    .pivot(index="month", columns="year", values="passengers")
)

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
import seaborn as sns
sns.set_theme(style="ticks")

# Load the planets dataset and initialize the figure
planets = sns.load_dataset("flights")
g = sns.JointGrid(data=planets, x="year", y="passengers", marginal_ticks=True)

# Set a log scaling on the y axis
g.ax_joint.set(yscale="log")

# Create an inset legend for the histogram colorbar
cax = g.figure.add_axes([.15, .55, .02, .2])

# Add the joint and marginal histogram plots
g.plot_joint(
    sns.histplot, discrete=(True, False),
    cmap="light:#03012d", pmax=.8, cbar=True, cbar_ax=cax
)
g.plot_marginals(sns.histplot, element="step", color="#03012d")

# %%
sns.boxenplot(data = df, x='year', y = 'passengers', hue='month')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Python_Ka_Chila\06_Assignment_Data_Visulization.ipynb Cell 15 line 2
#       <a href='vscode-notebook-cell:/d%3A/Python_Ka_Chila/06_Assignment_Data_Visulization.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> sns.boxenplot(data = df, x='year', y = 'passengers', hue='month')
# ----> <a href='vscode-notebook-cell:/d%3A/Python_Ka_Chila/06_Assignment_Data_Visulization.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> sns.b
#
# AttributeError: module 'seaborn' has no attribute 'b'

# %% [markdown]
# `2nd Data Set 'brain networks'`

# %%
df = sns.load_dataset('iris')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.scatterplot(data = df, x = 'sepal_length', y = 'sepal_width', hue = 'species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.barplot(data=df, x = 'species',y = 'sepal_width', hue = 'species')
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
import numpy as np
import seaborn as sns
sns.set_theme(style="ticks")

sns.jointplot(data = df, x='sepal_width', y='sepal_length', kind="hex", color="#4CD391")

# %%
import seaborn as sns
sns.set_theme(style="dark")

# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(data=df, x="species", y="sepal_width", hue="species",
               split=True, inner="quart", fill=False)
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")
df = sns.load_dataset("iris")

# "Melt" the dataset to "long-form" or "tidy" representation
df = df.melt(id_vars="species", var_name="measurement")

# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(
    data=df, x="value", y="measurement", hue="species",
    dodge=True, alpha=.5, zorder=1, legend=False,
)

# Show the conditional means, aligning each pointplot in the
# center of the strips by adjusting the width allotted to each
# category (.8 by default) by the number of hue levels
sns.pointplot(
    data=df, x="value", y="measurement", hue="species",
    dodge=.8 - .8 / 3, palette="dark", errorbar=None,
    markers="d", markersize=4, linestyle="none",
)

# Improve the legend
sns.move_legend(
    ax, loc="lower right", ncol=3, frameon=True, columnspacing=1, handletextpad=0,
)

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the brain networks dataset, select subset, and collapse the multi-index
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

used_networks = [1, 5, 6, 7, 8, 12, 13, 17]
used_columns = (df.columns
                  .get_level_values("network")
                  .astype(int)
                  .isin(used_networks))
df = df.loc[:, used_columns]

df.columns = df.columns.map("-".join)

# Compute a correlation matrix and convert to long-form
corr_mat = df.corr().stack().reset_index(name="correlation")

# Draw each cell as a scatter point with varying size and color
g = sns.relplot(
    data=corr_mat,
    x="level_0", y="level_1", hue="correlation", size="correlation",
    palette="vlag", hue_norm=(-1, 1), edgecolor=".7",
    height=10, sizes=(50, 250), size_norm=(-.2, .8),
)

# Tweak the figure to finalize
g.set(xlabel="", ylabel="", aspect="equal")
g.despine(left=True, bottom=True)
g.ax.margins(.02)
for label in g.ax.get_xticklabels():
    label.set_rotation(90)

# %%
import plotly.express as px

df = px.data.iris()
features = ["sepal_width", "sepal_length", "petal_width", "petal_length"]

fig = px.scatter_matrix(
    df,
    dimensions=features,
    color="species"
)
fig.update_traces(diagonal_visible=False)
fig.show()

# %% [markdown]
# ## git branch -m main main
# ### git fetch origin
# #### git branch -u origin/main main
# ##### git remote set-head origin -a
