# %%
# linear regression
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
# Single and mutiple linear regression
df = sns.load_dataset('tips')

# %%
sns.scatterplot(data = df, x = 'total_bill', y = 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# variable assigning
X = df[['total_bill']]
scale = StandardScaler()
# X = scale.fit_transform(X)
y = df['tip']

# %%
# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Call the model
model = LinearRegression()

# %%
# train model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# take out model intercep and slope and make and equatin
print(model.intercept_)
print(model.coef_)
print('y = ', model.intercept_,'+',model.coef_, '* X')
# Out:
# 0.7808474632142479
# [0.11182659]
# y =  0.7808474632142479 + [0.11182659] * X

# %%
# predict
y_pred = model.predict(X_test)
y_pred
# Out:
# array([1.59159026, 2.71656578, 2.60250265, 2.61815837, 2.5354067 ,
#        3.06770128, 4.78759426, 2.3251727 , 2.63493236, 5.85218342,
#        2.03777836, 2.46271941, 3.54408256, 1.6262565 , 2.64387849,
#        2.49850392, 1.74031962, 2.381086  , 3.82029424, 2.5354067 ,
#        2.51192311, 3.52283551, 1.93601616, 3.59999585, 6.17871707,
#        2.82615584, 2.46495594, 4.18037587, 2.57007294, 2.68078127,
#        2.37549467, 2.73333976, 2.66177075, 1.59159026, 3.46580394,
#        2.1250031 , 2.73893109, 1.86332888, 4.14235483, 3.14709816,
#        2.43923583, 2.59355652, 2.62039491, 3.38976186, 5.31541578,
#        1.89240379, 2.05343408, 2.56448161, 2.25248542])

# %%
# evaluate the model
print('MSE:', mean_squared_error(y_test, y_pred))
print('R2:', r2_score(y_test, y_pred))
print('MSE:', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# MSE: 1.3256452095538547
# R2: 0.2406259407523561
# MSE: 1.1513666703330676

# %%
model.predict([[1]])
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.89267406])

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_pred, %colors)

# %% [markdown]
# # When we are predicting the numerical continous data
# - numerci based numeric prediction
#     - If the output variable is categoricle
#     - then it is classification
# - if the data is dependent linearly,
#     - if we draw a line plot or KDE line should be straight
#     - there are more than one independant variables X, on which
#     - our output variable depends it will be presented as y
#     - y = mx + b
#         - the line in the plot of y against verticle column and
#         - X against X axis gives the value of these variables
#     - y = Bo + B1x (B = beta)
#     - y intercept, is point where betanot, crosses the center tendency line
#     - we use different method to fit all the points on the graph
#         - then line starts to get slopier and it almost fit to all the lines
#         - distance of all the points is equally spaced from the line
#     - ![image.png](attachment:1add069f-39f2-4ab7-8d4a-905a6fce8502.png)

# %% [markdown]
# - Distance from the line predicted and from the points is called as random errors
# - average vs squared average
# - mean squared error, ( get the square of all errors,  and then we will get the mean square)
# - MSE vs RMSE ![image.png](attachment:96e0083c-f8b9-4368-a68d-e99d24f5ac8f.png)

# %% [markdown]
# ![image.png](attachment:943d093f-b1b0-41c0-8961-0b32f0ed28cc.png)

# %% [markdown]
# # R_square =  1- (Residual sum of squared/total sum of squares)
