# %% [markdown]
# # `Model Book for SKLearn Coding`

# %%
# import libraries
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# ML librarries
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder, MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# import data
df = sns.load_dataset('tips')

# %%
# separate the features X and labels/targets Y
X = df[['total_bill']] # X should always be double simension. use double [[]]
y = df['tip']

# %%
# before train and test scalling
# scaler = StandardScaler()
# X = scaler.fit_transform(X)

# %%
# train test split
X_train, X_test, y_train, y_test =  train_test_split(X,y, test_size=0.2, train_size=0.8)

# %%
# # proprocess the data before and after train and test, but ammar preffer after
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)
# y_train = scaler.fit_transform(y_train.values.reshape(-1,1))
# y_test = scaler.transform(y_test.values.reshape(-1,1))

# %%
#Build the Model and call it
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# predict the values with model
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([6.23819455, 1.85765863, 4.91763733, 3.90039559, 2.25073075,
#        2.92442127, 3.13075833, 2.45603613, 3.06782553, 3.53311561,
#        1.90098942, 3.12663159, 2.34048737, 3.34328551, 4.56892768,
#        2.3807231 , 2.19398805, 2.06193233, 3.46708775, 2.5984087 ,
#        2.23731884, 3.3443172 , 4.58749802, 2.85736172, 4.13252479,
#        3.54549584, 2.77689026, 2.64483454, 4.0757821 , 5.67489436,
#        3.72088234, 2.59325028, 2.05574222, 3.5970801 , 1.8741656 ,
#        2.10732648, 3.47327786, 5.97614648, 3.03584328, 5.96582962,
#        5.1796854 , 2.49008174, 2.19192468, 2.06193233, 1.98146087,
#        1.99487278, 2.61491567, 2.28168131, 2.64483454])

# %%
model.predict([[80]])
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([9.24968403])

# %%
# Evaluate the mode
print('MSE:', mean_squared_error(y_test, y_pred))
print('R2:', r2_score(y_test, y_pred))
# Out:
# MSE: 1.2362086700475448
# R2: 0.5538513512172328

# %%
# Save model
import pickle
pickle.dump(model, open('./Data_Science_AI/6_month/models/model_01.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[64], line 3
#       1 # Save model
#       2 import pickle
# ----> 3 pickle.dump(model, open('./Data_Science_AI/6_month/models/model_01.pkl','wb'))
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './Data_Science_AI/6_month/models/model_01.pkl'
