# %% [markdown]
# # Evaluation materices
# - Named as confusin matrices
#   - Actual vs predicted
#   - ![image.png](attachment:image.png)
#   - How to get true negative and positive
#     - ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:c7644907-d362-495e-aeba-d6cd6284473c.png)

# %% [markdown]
# ![image.png](attachment:7560b222-2194-41ac-93af-d6e41cdfa098.png)
