# %% [markdown]
# # Linear Regression and Assumptions

# %% [markdown]
# ![image.png](attachment:ace0e859-456f-4e66-bf71-49afd59f705d.png)

# %% [markdown]
# # Multi-Linear Regression

# %% [markdown]
# ![image.png](attachment:e9b03aea-2adc-45d8-87ee-65a124a858a0.png)

# %% [markdown]
# ![image.png](attachment:27a85224-22a3-42dc-961f-724cc3ca6783.png)

# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ![image.png](attachment:8fcf123b-fd24-4b72-a3cf-7803bcd70dee.png)

# %% [markdown]
# ![image.png](attachment:1c864e7d-481b-4587-b619-ef126c64f68c.png)

# %% [markdown]
# ![image.png](attachment:adc3ccaa-d016-4840-8dc3-3a1c90a75046.png)

# %% [markdown]
# ![image.png](attachment:1f678897-af58-4004-bb6c-0f2dd6549b1e.png)
