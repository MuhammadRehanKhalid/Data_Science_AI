# %%
# L1_ and L2 Normalization
from sklearn.preprocessing import Normalizer

# %%
# l2 normalization usualy takes the square root of the sum of the squared values
data = [[1,1,1],[1,1,0],[1,0 ,0]] 
norma = Normalizer(norm='l2') #{'l1', 'l2', 'max'}.
print(norma.fit_transform(data))
# Out:
# [[0.57735027 0.57735027 0.57735027]
#  [0.70710678 0.70710678 0.        ]
#  [1.         0.         0.        ]]

# %%
# l1 transformaton making row value sum to one, rwo vise additon
data = [[1,1,1],[1,1,0],[1,0 ,0]]
norma = Normalizer(norm='l1') #{'l1', 'l2', 'max'}.
print(norma.fit_transform(data))
# Out:
# [[0.33333333 0.33333333 0.33333333]
#  [0.5        0.5        0.        ]
#  [1.         0.         0.        ]]

# %% [markdown]
# ---
# # Log transformation
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# example dataset with skewed dataset
df = pd.DataFrame({
    'values':[1,5,10,20,50,100,200,500,1000,2000,5000,10000,20000,50000,100000]
})
df.head()
# Out:
#    values
# 0       1
# 1       5
# 2      10
# 3      20
# 4      50

# %%
# plot
sns.histplot(data = df, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
df['log_values'] = np.log(df['values'])
df.head()
sns.histplot(df['log_values'],bins=10, kde=True)
# Out:
# <Axes: xlabel='log_values', ylabel='Count'>

# %%
for col in df.columns:
    sns.lineplot(df[col])
    plt.show()
