# %% [markdown]
# # Naive Bayes Algorithem and Theoram

# %% [markdown]
# ![image.png](attachment:1b619ee3-1783-4aa6-a018-f8d2f669b58c.png)

# %% [markdown]
# ![image.png](attachment:7097cbe1-a76a-4333-bfc2-6c68e40750c0.png)

# %% [markdown]
# ![image.png](attachment:75389e88-0689-4454-8ee8-accaca21e652.png)

# %% [markdown]
# ![image.png](attachment:afb07a28-e93a-4fce-adbf-520a674e5bbb.png)
