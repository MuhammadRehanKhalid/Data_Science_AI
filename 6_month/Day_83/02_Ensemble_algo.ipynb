# %% [markdown]
# # Boosting

# %% [markdown]
# ![image.png](attachment:c2ad9056-888f-4d23-81fd-91cdbf1fd953.png)

# %% [markdown]
# # Various Methods of Boosting
# - `AdaBoost (Adaptive Boosting)`
#     - ![image.png](attachment:8105186c-a761-44a3-9f4a-8fcc3bd3b3d7.png)
# - `Gradient Boosting`
# - based on residual errors
#     - ![image.png](attachment:8dccdf0a-22bb-4f65-ae60-1238a5d738c9.png)
# - `CatBoost (Categorical Boosting)`
# - `SGB (Stochastic gradient Boosting)`
#     - ![image.png](attachment:89ba929d-e514-4051-a0a1-708ac85ea2ca.png)
# - `LPBoost (Linear programming Boosting`
# - `TotalBoosting`
#     - contains Adaboost and LPBoost
# ![image.png](attachment:b75ac657-4a22-4bd2-b449-b7361e866651.png)
# ![image.png](attachment:a1183b20-6380-4e1d-bba2-cc59895c8135.png)
