# %% [markdown]
# # `Notebook by Muhammad Rehan Khalid`

# %% [markdown]
# ## Ensemble algorithms
# `When we use multiple algorithms except one only`

# %% [markdown]
# ### emsemble family (Boosting Models)
# - ![image.png](attachment:189cea76-de06-4cea-bb30-8eb30269d6cf.png)
# - Bagging,
# - Boosting, (Bootstrapping, divison of data into subsets, then we aggregate and then ensemble)
# - Stacking
# - ![image.png](attachment:0002b930-f3bc-4717-aa99-067af86b0bb3.png)

# %% [markdown]
# - ![image.png](attachment:d7d2b6b6-98f7-4bd2-9d76-7f91e1520c52.png)
