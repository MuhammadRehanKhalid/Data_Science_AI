# %% [markdown]
# # `Ensemble vs ANN`

# %% [markdown]
# ![image.png](attachment:27f0b431-9e24-455c-977b-50a80b86e512.png)
# ![image.png](attachment:03f43b58-aadb-4889-bd9f-fb33cf47998b.png)
# ![image.png](attachment:73b11235-d26f-4f4a-9c31-cc3b9f8e3fd2.png)
# ![image.png](attachment:5c8435b1-bcc4-4813-b20f-bc5bbcdcfa52.png)
