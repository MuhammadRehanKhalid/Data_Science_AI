# %%
import matplotlib.font_manager

fonts = [f.name for f in matplotlib.font_manager.fontManager.ttflist]
print(fonts)
# Out:
# ['DejaVu Sans Mono', 'STIXSizeOneSym', 'DejaVu Serif Display', 'cmsy10', 'DejaVu Sans', 'DejaVu Sans', 'STIXSizeFourSym', 'DejaVu Serif', 'cmmi10', 'STIXGeneral', 'cmtt10', 'DejaVu Sans Mono', 'STIXGeneral', 'STIXGeneral', 'STIXSizeFourSym', 'STIXNonUnicode', 'DejaVu Serif', 'STIXSizeThreeSym', 'STIXSizeThreeSym', 'DejaVu Sans Mono', 'cmex10', 'STIXSizeFiveSym', 'cmss10', 'cmr10', 'DejaVu Sans Mono', 'DejaVu Serif', 'STIXNonUnicode', 'DejaVu Serif', 'DejaVu Sans Display', 'STIXNonUnicode', 'STIXGeneral', 'STIXSizeOneSym', 'STIXSizeTwoSym', 'STIXSizeTwoSym', 'cmb10', 'STIXNonUnicode', 'DejaVu Sans', 'DejaVu Sans', 'DejaVu Sans Mono', 'DejaVu Sans', 'DejaVu Serif', 'DejaVu Sans Mono', 'DejaVu Sans', 'DejaVu Serif']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample data
df = pd.read_excel("./microalgae_Exp_2.xlsx")

# Create a DataFrame
# df = pd.DataFrame(data)

# Separate the data by variety
df_variety_08 = df[df['Variety'] == 'BTN-R08']
df_variety_10 = df[df['Variety'] == 'BTN-R10']

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 7), sharey=True)

# Plot for BTN-R08
sns.lineplot(ax=axes[0], data=df_variety_08, x='Day', y='pH_change', hue='Media', marker='o')
axes[0].set_title('pH Change Over Time for BTN-R08', fontname='DejaVu Serif', fontweight='bold')
axes[0].set_xlabel('Cultivation Days', fontname='DejaVu Serif', fontweight='bold')
axes[0].set_ylabel('pH Change', fontname='DejaVu Serif', fontweight='bold')
axes[0].legend(title='Media', title_fontsize='13', prop={'family': 'DejaVu Serif', 'weight': 'bold'})
axes[0].grid(False)

# Plot for BTN-R10
sns.lineplot(ax=axes[1], data=df_variety_10, x='Day', y='pH_change', hue='Media', marker='o')
axes[1].set_title('pH Change Over Time for BTN-R10', fontname='DejaVu Serif', fontweight='bold')
axes[1].set_xlabel('Cultivation Days', fontname='DejaVu Serif', fontweight='bold')
axes[1].set_ylabel('pH Change', fontname='DejaVu Serif', fontweight='bold')
axes[1].legend(title='Media', title_fontsize='13', prop={'family': 'DejaVu Serif', 'weight': 'bold'})
axes[1].grid(False)

# Adjust layout
plt.tight_layout()
# Save the plot as SVG
plt.savefig('plot.png', format='png', dpi=300, bbox_inches='tight')
# Show the plot
plt.show()

# %%
df.to_excel("microalgae_sample.xlsx", index = False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample data
data = {
    'Day': ['Day7', 'Day14', 'Day21', 'Day28'] * 8,
    'Media': ['BBM']*8 + ['BG11']*8 + ['MBM']*8 + ['MBG11']*8,
    'Variety': ['BTN-R08']*4 + ['BTN-R10']*4 + ['BTN-R08']*4 + ['BTN-R10']*4 +
               ['BTN-R08']*4 + ['BTN-R10']*4 + ['BTN-R08']*4 + ['BTN-R10']*4,
    'pH_change': [1.1, 1.3, 1.4, 1.2, 1.2, 1.5, 1.7, 1.6, 1.3, 1.4, 1.5, 1.7, 
                  1.1, 1.2, 1.3, 1.5, 1.2, 1.3, 1.4, 1.6, 1.3, 1.5, 1.6, 1.8, 
                  1.2, 1.4, 1.5, 1.3, 1.1, 1.2, 1.4, 1.7]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Create a FacetGrid
g = sns.FacetGrid(df, col="Media", row="Variety", margin_titles=True, height=4, aspect=1.5)
g.map(sns.lineplot, "Day", "pH_change", marker="o")

# Adjust the titles and layout
g.set_axis_labels("Cultivation Days", "pH Change")
g.set_titles(col_template="{col_name}", row_template="{row_name}")
g.add_legend()

# Improve the spacing
plt.subplots_adjust(top=0.9)
g.fig.suptitle('pH Change Over Time for Different Media and Microalgae Varieties', fontsize=16)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample data
data = {
    'Day': ['Day7', 'Day14', 'Day21', 'Day28'] * 8,
    'Media': ['BBM']*8 + ['BG11']*8 + ['MBM']*8 + ['MBG11']*8,
    'Variety': ['BTN-R08']*4 + ['BTN-R10']*4 + ['BTN-R08']*4 + ['BTN-R10']*4 +
               ['BTN-R08']*4 + ['BTN-R10']*4 + ['BTN-R08']*4 + ['BTN-R10']*4,
    'pH_change': [1.1, 1.3, 1.4, 1.2, 1.2, 1.5, 1.7, 1.6, 1.3, 1.4, 1.5, 1.7, 
                  1.1, 1.2, 1.3, 1.5, 1.2, 1.3, 1.4, 1.6, 1.3, 1.5, 1.6, 1.8, 
                  1.2, 1.4, 1.5, 1.3, 1.1, 1.2, 1.4, 1.7]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Set the color palette
palette = sns.color_palette("Set2", n_colors=4)

# Initialize the matplotlib figure
plt.figure(figsize=(14, 8))

# Create a bar plot
bar_plot = sns.barplot(
    data=df, x='Day', y='pH_change', hue='Media', ci=None, palette=palette, 
    dodge=True
)

# Customize the plot
plt.title('pH Change Over Time for Different Media and Microalgae Varieties')
plt.xlabel('Cultivation Days')
plt.ylabel('pH Change')
plt.legend(title='Media', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, linestyle='--', linewidth=0.7)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_867/1011515195.py:26: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   bar_plot = sns.barplot(

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample data
data = {
    'Day': ['Day7', 'Day14', 'Day21', 'Day28'] * 8,
    'Media': ['BBM']*8 + ['BG11']*8 + ['MBBM']*8 + ['MBG11']*8,
    'Variety': ['BTN-R08']*4 + ['BTN-R10']*4 + ['BTN-R08']*4 + ['BTN-R10']*4 +
               ['BTN-R08']*4 + ['BTN-R10']*4 + ['BTN-R08']*4 + ['BTN-R10']*4,
    'pH_change': [1.1, 1.3, 1.4, 1.2, 1.2, 1.5, 1.7, 1.6, 1.3, 1.4, 1.5, 1.7, 
                  1.1, 1.2, 1.3, 1.5, 1.2, 1.3, 1.4, 1.6, 1.3, 1.5, 1.6, 1.8, 
                  1.2, 1.4, 1.5, 1.3, 1.1, 1.2, 1.4, 1.7]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Aggregate the data
agg_data = df.groupby(['Day', 'Media', 'Variety'])['pH_change'].sum().reset_index()

# Plot donut charts
days = df['Day'].unique()
varieties = df['Variety'].unique()

fig, axes = plt.subplots(len(days), len(varieties), figsize=(14, 14))

for i, day in enumerate(days):
    for j, variety in enumerate(varieties):
        subset = agg_data[(agg_data['Day'] == day) & (agg_data['Variety'] == variety)]
        ax = axes[i, j]

        wedges, texts, autotexts = ax.pie(
            subset['pH_change'], labels=subset['Media'], autopct='%1.1f%%',
            startangle=140, wedgeprops=dict(width=0.3, edgecolor='w')
        )

        # Draw a circle at the center to make it a donut
        centre_circle = plt.Circle((0, 0), 0.70, fc='white')
        ax.add_artist(centre_circle)

        # Equal aspect ratio ensures that pie is drawn as a circle
        ax.axis('equal')  
        ax.set_title(f"{day} - {variety}")

plt.suptitle('Proportion of pH Change by Media and Variety on Different Days', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample data
data = {
    'Day': ['Day7', 'Day14', 'Day21', 'Day28'] * 8,
    'Media': ['BBM']*8 + ['BG11']*8 + ['MBBM']*8 + ['MBG11']*8,
    'Variety': ['BTN-R08']*4 + ['BTN-R10']*4 + ['BTN-R08']*4 + ['BTN-R10']*4 +
               ['BTN-R08']*4 + ['BTN-R10']*4 + ['BTN-R08']*4 + ['BTN-R10']*4,
    'pH_change': [1.1, 1.3, 1.4, 1.2, 1.2, 1.5, 1.7, 1.6, 1.3, 1.4, 1.5, 1.7, 
                  1.1, 1.2, 1.3, 1.5, 1.2, 1.3, 1.4, 1.6, 1.3, 1.5, 1.6, 1.8, 
                  1.2, 1.4, 1.5, 1.3, 1.1, 1.2, 1.4, 1.7]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Aggregate the data
agg_data = df.groupby(['Day', 'Media', 'Variety'])['pH_change'].sum().reset_index()

# Plot donut charts
days = df['Day'].unique()
varieties = df['Variety'].unique()

fig, axes = plt.subplots(len(days), len(varieties), figsize=(14, 14))

for i, day in enumerate(days):
    for j, variety in enumerate(varieties):
        subset = agg_data[(agg_data['Day'] == day) & (agg_data['Variety'] == variety)]
        ax = axes[i, j]

        wedges, texts, autotexts = ax.pie(
            subset['pH_change'], labels=subset['Media'], autopct='%1.1f%%',
            startangle=140, wedgeprops=dict(width=0.3, edgecolor='w')
        )

        # Draw a circle at the center to make it a donut
        centre_circle = plt.Circle((0, 0), 0.70, fc='white')
        ax.add_artist(centre_circle)

        # Equal aspect ratio ensures that pie is drawn as a circle
        ax.axis('equal')  
        ax.set_title(f"{day} - {variety}")

        # Adjust label positions
        for text in texts:
            text.set_horizontalalignment('center')
            text.set_verticalalignment('center')
            text.set_fontsize(10)

        for autotext in autotexts:
            autotext.set_color('black')
            autotext.set_fontsize(8)
            autotext.set_weight('bold')

plt.suptitle('Proportion of pH Change by Media and Variety on Different Days', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Sample data with 'MBM' changed to 'MBBM'
data = {
    'Day': ['Day7', 'Day14', 'Day21', 'Day28'] * 8,
    'Media': ['BBM']*8 + ['BG11']*8 + ['MBBM']*8 + ['MBG11']*8,
    'Variety': ['BTN-R08']*4 + ['BTN-R10']*4 + ['BTN-R08']*4 + ['BTN-R10']*4 +
               ['BTN-R08']*4 + ['BTN-R10']*4 + ['BTN-R08']*4 + ['BTN-R10']*4,
    'pH_change': [1.1, 1.3, 1.4, 1.2, 1.2, 1.5, 1.7, 1.6, 1.3, 1.4, 1.5, 1.7, 
                  1.1, 1.2, 1.3, 1.5, 1.2, 1.3, 1.4, 1.6, 1.3, 1.5, 1.6, 1.8, 
                  1.2, 1.4, 1.5, 1.3, 1.1, 1.2, 1.4, 1.7]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Aggregate the data
agg_data = df.groupby(['Day', 'Media', 'Variety'])['pH_change'].sum().reset_index()

# Prepare data for the donut chart
outer_labels = df['Day'].unique()
middle_labels = df['Media'].unique()
inner_labels = df['Variety'].unique()

outer_sizes = [agg_data[agg_data['Day'] == day]['pH_change'].sum() for day in outer_labels]
middle_sizes = [agg_data[(agg_data['Day'] == day) & (agg_data['Media'] == media)]['pH_change'].sum()
                for day in outer_labels for media in middle_labels]
inner_sizes = [agg_data[(agg_data['Day'] == day) & (agg_data['Media'] == media) & (agg_data['Variety'] == variety)]['pH_change'].sum()
               for day in outer_labels for media in middle_labels for variety in inner_labels]

# Colors
outer_colors = plt.cm.Paired(range(len(outer_labels)))
middle_colors = plt.cm.Paired(range(len(middle_labels) * len(outer_labels)))
inner_colors = plt.cm.Paired(range(len(inner_labels) * len(middle_labels) * len(outer_labels)))

fig, ax = plt.subplots(figsize=(10, 10))

# Outer ring
wedges, texts = ax.pie(
    outer_sizes, radius=1.3, labels=outer_labels, labeldistance=0.85,
    colors=outer_colors, wedgeprops=dict(width=0.3, edgecolor='w')
)

# Middle ring
wedges, texts = ax.pie(
    middle_sizes, radius=1, labeldistance=0.75,
    colors=middle_colors, wedgeprops=dict(width=0.3, edgecolor='w')
)

# Inner ring
wedges, texts = ax.pie(
    inner_sizes, radius=0.7, labeldistance=0.65,
    colors=inner_colors, wedgeprops=dict(width=0.3, edgecolor='w')
)

# Adding labels for middle and inner rings
bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    if i < len(middle_sizes):
        ax.annotate(middle_labels[i % len(middle_labels)], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                    horizontalalignment=horizontalalignment, **kw)
    elif i < len(inner_sizes) + len(middle_sizes):
        ax.annotate(inner_labels[i % len(inner_labels)], xy=(x, y), xytext=(0.75*np.sign(x), 0.75*y),
                    horizontalalignment=horizontalalignment, **kw)

# Draw center circle
centre_circle = plt.Circle((0, 0), 0.4, fc='white')
ax.add_artist(centre_circle)

# Equal aspect ratio ensures that pie is drawn as a circle
ax.axis('equal')  
plt.title('Proportion of pH Change by Media and Variety on Different Days')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Sample data with 'MBM' changed to 'MBBM'
data = {
    'Day': ['Day7', 'Day14', 'Day21', 'Day28'] * 8,
    'Media': ['BBM']*8 + ['BG11']*8 + ['MBBM']*8 + ['MBG11']*8,
    'Variety': ['BTN-R08']*4 + ['BTN-R10']*4 + ['BTN-R08']*4 + ['BTN-R10']*4 +
                ['BTN-R08']*4 + ['BTN-R10']*4 + ['BTN-R08']*4 + ['BTN-R10']*4,
    'pH_change': [1.1, 1.3, 1.4, 1.2, 1.2, 1.5, 1.7, 1.6, 1.3, 1.4, 1.5, 1.7, 
                    1.1, 1.2, 1.3, 1.5, 1.2, 1.3, 1.4, 1.6, 1.3, 1.5, 1.6, 1.8, 
                    1.2, 1.4, 1.5, 1.3, 1.1, 1.2, 1.4, 1.7]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Aggregate the data
agg_data = df.groupby(['Day', 'Media', 'Variety'])['pH_change'].sum().reset_index()

# Prepare data for the donut chart
outer_labels = df['Day'].unique()
middle_labels = df['Media'].unique()
inner_labels = df['Variety'].unique()

outer_sizes = [agg_data[agg_data['Day'] == day]['pH_change'].sum() for day in outer_labels]
middle_sizes = [agg_data[(agg_data['Day'] == day) & (agg_data['Media'] == media)]['pH_change'].sum()
                for day in outer_labels for media in middle_labels]
inner_sizes = [agg_data[(agg_data['Day'] == day) & (agg_data['Media'] == media) & (agg_data['Variety'] == variety)]['pH_change'].sum()
                for day in outer_labels for media in middle_labels for variety in inner_labels]

# Colors
outer_colors = plt.cm.Paired(range(len(outer_labels)))
middle_colors = plt.cm.Paired(range(len(middle_labels) * len(outer_labels)))
inner_colors = plt.cm.Paired(range(len(inner_labels) * len(middle_labels) * len(outer_labels)))

fig, ax = plt.subplots(figsize=(10, 10))

# Outer ring
wedges, texts = ax.pie(
    outer_sizes, radius=1.3, labels=outer_labels, labeldistance=0.85,
    colors=outer_colors, wedgeprops=dict(width=0.3, edgecolor='w'), textprops={'fontsize': 12}
)

# Middle ring
wedges, texts = ax.pie(
    middle_sizes, radius=1, labeldistance=0.75,
    colors=middle_colors, wedgeprops=dict(width=0.3, edgecolor='w'), textprops={'fontsize': 10}
)

# Inner ring
wedges, texts = ax.pie(
    inner_sizes, radius=0.7, labeldistance=0.65,
    colors=inner_colors, wedgeprops=dict(width=0.3, edgecolor='w'), textprops={'fontsize': 8}
)

# Adding labels for middle and inner rings
bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
            bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    if i < len(middle_sizes):
        ax.annotate(middle_labels[i % len(middle_labels)], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                    horizontalalignment=horizontalalignment, **kw)
    elif i < len(inner_sizes) + len(middle_sizes):
        ax.annotate(inner_labels[i % len(inner_labels)], xy=(x, y), xytext=(0.75*np.sign(x), 0.75*y),
                    horizontalalignment=horizontalalignment, **kw)

# Draw center circle
centre_circle = plt.Circle((0, 0), 0.4, fc='white')
ax.add_artist(centre_circle)

# Equal aspect

ax.axis('equal')
plt.title('Proportion of pH Change by Media and Variety on Different Days', fontsize=16)
plt.show()
