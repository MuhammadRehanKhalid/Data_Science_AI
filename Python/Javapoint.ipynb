# %% [markdown]
# # Muhammad Rehan Khalid
# * @author
# * @version 1.0
# * @since 2020-04-10
# > Licensed

# %%
#-----------------------Coorelation--------------------#
import seaborn as sns
import matplotlib.pyplot as plt

# load data for correlation plot
corr_data = sns.load_dataset('iris')
corr_data = corr_data.drop(columns=['species'])  # drop non-numeric column for correlation
corr_data = corr_data.corr()  # calculate correlation matrix

# create a correlation plot
sns.set(font='Times New Roman')
plt.figure(figsize=(8, 8))
sns.heatmap(corr_data, annot=True, cmap='coolwarm', square=True)
plt.title('Correlation plot', fontsize=18, fontweight='bold', fontname='Times New Roman')
plt.xlabel('Features', fontsize=14, fontname='Times New Roman')
plt.ylabel('Features', fontsize=14, fontname='Times New Roman')
plt.xticks(fontname='Times New Roman')
plt.yticks(fontname='Times New Roman')
plt.show()

# %%
print('Hello World')
# Out:
# Hello World

# %%
name = input("What is your name?")
print(f"Hello, {name}")
# Out:
# Hello, Rehan

# %% [markdown]
# Muhammad Rehan starting javapoint coding
# ## From Variables
# - Lets start
# * 02-04-2023

# %%
x,y,z = "Orange","Banana","Cherry"
print(x)
print(y)
print(z)

def add(a,b,c):
    print(a*b*c)
add(5,2,7)
def add():
    a=5
    b=2
    c=7
    return a*b*c
print(add())
print(1,2,3,4,5)
# Out:
# Orange
# Banana
# Cherry
# 70
# 70
# 1 2 3 4 5

# %%
#tokens in details
